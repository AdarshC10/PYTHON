# %%
import pandas as pd
import numpy as np

# %%
cereals = pd.read_csv("cereals_data.csv")
cereals
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100%_Bran   N    C        70        4    1     130   10.0
# 1           100%_Natural_Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran_with_Extra_Fiber   K    C        50        4    0     140   14.0
# 4              Almond_Delight   R    C       110        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat_Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 76        Wheaties_Honey_Gold   G    C       110        2    1     200    1.0
#
# ...

# %% [markdown]
# #### 1. Add index name fast on name

# %%
cereals.index.name = "fast"

cereals
# Out:
#                            name mfr type  calories  protein  fat  sodium  \
# fast
# 0                     100%_Bran   N    C        70        4    1     130
# 1             100%_Natural_Bran   Q    C       120        3    5      15
# 2                      All-Bran   K    C        70        4    1     260
# 3     All-Bran_with_Extra_Fiber   K    C        50        4    0     140
# 4                Almond_Delight   R    C       110        2    2     200
# ...                         ...  ..  ...       ...      ...  ...     ...
# 72                      Triples   G    C       110        2    1     250
# 73                         Trix   G    C       110        1    1     140
# 74                   Wheat_Chex   R    C       100        3    1     230
# 75                     Wheaties   G    C       100        3    1     200
# 76          Wheaties_Honey_Gold   G    C       110        2    1     200
#
#       fiber  carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# fast
# ...

# %% [markdown]
# #### 2. Describe the schema of table

# %%
cereals.describe()
# Out:
#          calories    protein        fat      sodium      fiber      carbo  \
# count   77.000000  77.000000  77.000000   77.000000  77.000000  76.000000
# mean   106.883117   2.545455   1.012987  159.675325   2.151948  14.802632
# std     19.484119   1.094790   1.006473   83.832295   2.383364   3.907326
# min     50.000000   1.000000   0.000000    0.000000   0.000000   5.000000
# 25%    100.000000   2.000000   0.000000  130.000000   1.000000  12.000000
# 50%    110.000000   3.000000   1.000000  180.000000   2.000000  14.500000
# 75%    110.000000   3.000000   2.000000  210.000000   3.000000  17.000000
# max    160.000000   6.000000   5.000000  320.000000  14.000000  23.000000
#
#           sugars      potass    vitamins      shelf     weight       cups  \
# count  76.000000   75.000000   77.000000  77.000000  77.000000  77.000000
# mean    7.026316   98.666667   28.246753   2.207792   1.029610   0.821039
# std     4.378656   70.410636   22.342523   0.832524   0.150477   0.232716
# ...

# %% [markdown]
# #### 3. Create view name as see where users can not see type column [first run appropriate query
# then create view]

# %%
see =cereals.drop('type',axis=1)
see
# Out:
#                            name mfr  calories  protein  fat  sodium  fiber  \
# fast
# 0                     100%_Bran   N        70        4    1     130   10.0
# 1             100%_Natural_Bran   Q       120        3    5      15    2.0
# 2                      All-Bran   K        70        4    1     260    9.0
# 3     All-Bran_with_Extra_Fiber   K        50        4    0     140   14.0
# 4                Almond_Delight   R       110        2    2     200    1.0
# ...                         ...  ..       ...      ...  ...     ...    ...
# 72                      Triples   G       110        2    1     250    0.0
# 73                         Trix   G       110        1    1     140    0.0
# 74                   Wheat_Chex   R       100        3    1     230    3.0
# 75                     Wheaties   G       100        3    1     200    3.0
# 76          Wheaties_Honey_Gold   G       110        2    1     200    1.0
#
# ...

# %% [markdown]
# #### 4. Rename the view as saw

# %%
saw = see.copy()
saw
# Out:
#                            name mfr  calories  protein  fat  sodium  fiber  \
# fast
# 0                     100%_Bran   N        70        4    1     130   10.0
# 1             100%_Natural_Bran   Q       120        3    5      15    2.0
# 2                      All-Bran   K        70        4    1     260    9.0
# 3     All-Bran_with_Extra_Fiber   K        50        4    0     140   14.0
# 4                Almond_Delight   R       110        2    2     200    1.0
# ...                         ...  ..       ...      ...  ...     ...    ...
# 72                      Triples   G       110        2    1     250    0.0
# 73                         Trix   G       110        1    1     140    0.0
# 74                   Wheat_Chex   R       100        3    1     230    3.0
# 75                     Wheaties   G       100        3    1     200    3.0
# 76          Wheaties_Honey_Gold   G       110        2    1     200    1.0
#
# ...

# %% [markdown]
# #### 5. Count how many are cold cereals

# %%
count_cold = cereals.type.value_counts().reset_index()
count_cold.iloc[0]
# Out:
# type      C
# count    74
# Name: 0, dtype: object

# %% [markdown]
# #### 6. Count how many cereals are kept in shelf 3

# %%
cereals[cereals.shelf == 3]
# Out:
#                                         name mfr type  calories  protein  fat  \
# fast
# 0                                  100%_Bran   N    C        70        4    1
# 1                          100%_Natural_Bran   Q    C       120        3    5
# 2                                   All-Bran   K    C        70        4    1
# 3                  All-Bran_with_Extra_Fiber   K    C        50        4    0
# 4                             Almond_Delight   R    C       110        2    2
# 7                                    Basic_4   G    C       130        3    2
# 9                                Bran_Flakes   P    C        90        3    0
# 13                                  Clusters   G    C       110        3    2
# 19                        Cracklin'_Oat_Bran   K    C       110        3    3
# 21                                   Crispix   K    C       110        2    0
# 22                    Crispy_Wheat_&_Raisins   G    C       100        2    1
# ...

# %% [markdown]
# #### 7. Arrange the table from high to low according to ratings

# %%
cereals.sort_values("rating",ascending=False)
# Out:
#                            name mfr type  calories  protein  fat  sodium  \
# fast
# 3     All-Bran_with_Extra_Fiber   K    C        50        4    0     140
# 64       Shredded_Wheat_'n'Bran   N    C        90        3    0       0
# 65    Shredded_Wheat_spoon_size   N    C        90        3    0       0
# 0                     100%_Bran   N    C        70        4    1     130
# 63               Shredded_Wheat   N    C        80        2    0       0
# ...                         ...  ..  ...       ...      ...  ...     ...
# 14                  Cocoa_Puffs   G    C       110        1    1     180
# 18                Count_Chocula   G    C       110        1    1     180
# 35             Honey_Graham_Ohs   Q    C       120        1    2     220
# 12        Cinnamon_Toast_Crunch   G    C       120        1    3     210
# 10                 Cap'n'Crunch   Q    C       120        1    2     220
#
#       fiber  carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# fast
# ...

# %% [markdown]
# #### 8. Suggest some column/s which can be Primary key

# %% [markdown]
# #### 9. Find average of calories of hot cereal and cold cereal in one query

# %%
average_cal = cereals.groupby('type')['calories'].mean().reset_index()
average_cal
# Out:
#   type    calories
# 0    C  107.162162
# 1    H  100.000000

# %% [markdown]
# #### 10. Add new column as HL_Calories where more than average calories should be categorized as
# #HIGH and less than average calories should be categorized as LOW

# %%
avg_cal = cereals.calories.mean()
cereals["HL_Calories"] = cereals["calories"].apply(lambda x: "High" if x>avg_cal else "Low" )
cereals
# Out:
#                            name mfr type  calories  protein  fat  sodium  \
# fast
# 0                     100%_Bran   N    C        70        4    1     130
# 1             100%_Natural_Bran   Q    C       120        3    5      15
# 2                      All-Bran   K    C        70        4    1     260
# 3     All-Bran_with_Extra_Fiber   K    C        50        4    0     140
# 4                Almond_Delight   R    C       110        2    2     200
# ...                         ...  ..  ...       ...      ...  ...     ...
# 72                      Triples   G    C       110        2    1     250
# 73                         Trix   G    C       110        1    1     140
# 74                   Wheat_Chex   R    C       100        3    1     230
# 75                     Wheaties   G    C       100        3    1     200
# 76          Wheaties_Honey_Gold   G    C       110        2    1     200
#
#       fiber  carbo  sugars  potass  vitamins  shelf  weight  cups     rating  \
# ...

# %% [markdown]
# #### 11. List only those cereals whose name begins with B

# %%
cereals[cereals.name.str.lower().str.startswith('b')]
# Out:
#              name mfr type  calories  protein  fat  sodium  fiber  carbo  \
# fast
# 7         Basic_4   G    C       130        3    2     210    2.0   18.0
# 8       Bran_Chex   R    C        90        2    1     200    4.0   15.0
# 9     Bran_Flakes   P    C        90        3    0     210    5.0   13.0
#
#       sugars  potass  vitamins  shelf  weight  cups     rating HL_Calories
# fast
# 7        8.0   100.0        25      3    1.33  0.75  37.038562        High
# 8        6.0   125.0        25      1    1.00  0.67  49.120253         Low
# 9        5.0   190.0        25      3    1.00  0.67  53.313813         Low

# %% [markdown]
# #### 12. List only those cereals whose name begins with F

# %%
cereals[cereals.name.str.lower().str.startswith('f')]
# Out:
#                                         name mfr type  calories  protein  fat  \
# fast
# 24                               Froot_Loops   K    C       110        2    1
# 25                            Frosted_Flakes   K    C       110        1    0
# 26                       Frosted_Mini-Wheats   K    C       100        3    0
# 27    Fruit_&_Fibre_Dates,_Walnuts,_and_Oats   P    C       120        3    2
# 28                             Fruitful_Bran   K    C       120        3    0
# 29                            Fruity_Pebbles   P    C       110        1    1
#
#       sodium  fiber  carbo  sugars  potass  vitamins  shelf  weight  cups  \
# fast
# 24       125    1.0   11.0    13.0    30.0        25      2    1.00  1.00
# 25       200    1.0   14.0    11.0    25.0        25      1    1.00  0.75
# 26         0    3.0   14.0     7.0   100.0        25      2    1.00  0.80
# 27       160    5.0   12.0    10.0   200.0        25      3    1.25  0.67
# ...

# %% [markdown]
# #### 13. List only those cereals whose name ends with s

# %%
cereals[cereals.name.str.lower().str.endswith("s")]
# Out:
#                                         name mfr type  calories  protein  fat  \
# fast
# 5                    Apple_Cinnamon_Cheerios   G    C       110        2    2
# 6                                Apple_Jacks   K    C       110        2    0
# 9                                Bran_Flakes   P    C        90        3    0
# 11                                  Cheerios   G    C       110        6    2
# 13                                  Clusters   G    C       110        3    2
# 14                               Cocoa_Puffs   G    C       110        1    1
# 16                               Corn_Flakes   K    C       100        2    0
# 17                                 Corn_Pops   K    C       110        1    0
# 22                    Crispy_Wheat_&_Raisins   G    C       100        2    1
# 24                               Froot_Loops   K    C       110        2    1
# 25                            Frosted_Flakes   K    C       110        1    0
# ...

# %% [markdown]
# #### 14. Select only those records which are HIGH in column HL_calories and mail to
# #jeevan.raj@imarticus.com [save/name your file as <your first name_cereals_high>]

# %%
cereals[cereals.HL_Calories =="High"]
# Out:
#                                         name mfr type  calories  protein  fat  \
# fast
# 1                          100%_Natural_Bran   Q    C       120        3    5
# 4                             Almond_Delight   R    C       110        2    2
# 5                    Apple_Cinnamon_Cheerios   G    C       110        2    2
# 6                                Apple_Jacks   K    C       110        2    0
# 7                                    Basic_4   G    C       130        3    2
# 10                              Cap'n'Crunch   Q    C       120        1    2
# 11                                  Cheerios   G    C       110        6    2
# 12                     Cinnamon_Toast_Crunch   G    C       120        1    3
# 13                                  Clusters   G    C       110        3    2
# 14                               Cocoa_Puffs   G    C       110        1    1
# 15                                 Corn_Chex   R    C       110        2    0
# ...

# %% [markdown]
# #### 15. Find maximum of ratings

# %%
cereals.rating.max()
# Out:
# 93.704912

# %% [markdown]
# #### 16. Find average ratings of those were High and Low calories

# %%
cereals.groupby('HL_Calories')['rating'].mean().reset_index()
# Out:
#   HL_Calories     rating
# 0        High  34.919791
# 1         Low  54.800971

# %% [markdown]
# #### 17. Craete two examples of Sub Queries of your choice and give explanation in the script
# itself with r

# %%
#one sub query to get the Average rating where the condition HL_calories is high

cereals[cereals.rating >(cereals[cereals.HL_Calories == "High"]['rating'].mean())]
# Out:
#                                         name mfr type  calories  protein  fat  \
# fast
# 0                                  100%_Bran   N    C        70        4    1
# 2                                   All-Bran   K    C        70        4    1
# 3                  All-Bran_with_Extra_Fiber   K    C        50        4    0
# 7                                    Basic_4   G    C       130        3    2
# 8                                  Bran_Chex   R    C        90        2    1
# 9                                Bran_Flakes   P    C        90        3    0
# 11                                  Cheerios   G    C       110        6    2
# 13                                  Clusters   G    C       110        3    2
# 15                                 Corn_Chex   R    C       110        2    0
# 16                               Corn_Flakes   K    C       100        2    0
# 17                                 Corn_Pops   K    C       110        1    0
# ...

# %% [markdown]
# #### 18. Remove column fat

# %%
cereals.drop('fat',axis =1)
# Out:
#                          name mfr type  calories  protein  sodium  fiber  \
# 0                   100%_Bran   N    C        70        4     130   10.0
# 1           100%_Natural_Bran   Q    C       120        3      15    2.0
# 2                    All-Bran   K    C        70        4     260    9.0
# 3   All-Bran_with_Extra_Fiber   K    C        50        4     140   14.0
# 4              Almond_Delight   R    C       110        2     200    1.0
# ..                        ...  ..  ...       ...      ...     ...    ...
# 72                    Triples   G    C       110        2     250    0.0
# 73                       Trix   G    C       110        1     140    0.0
# 74                 Wheat_Chex   R    C       100        3     230    3.0
# 75                   Wheaties   G    C       100        3     200    3.0
# 76        Wheaties_Honey_Gold   G    C       110        2     200    1.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating  \
# ...

# %% [markdown]
# #### 19. Count records for each manufacturer [mfr]

# %%
cereals.mfr.value_counts()
# Out:
# mfr
# K    23
# G    22
# P     9
# R     8
# Q     8
# N     6
# A     1
# Name: count, dtype: int64

# %% [markdown]
# #### 20. Select name, calories and ratings only

# %%
cereals[['name','calories','rating']]
# Out:
#                          name  calories     rating
# 0                   100%_Bran        70  68.402973
# 1           100%_Natural_Bran       120  33.983679
# 2                    All-Bran        70  59.425505
# 3   All-Bran_with_Extra_Fiber        50  93.704912
# 4              Almond_Delight       110  34.384843
# ..                        ...       ...        ...
# 72                    Triples       110  39.106174
# 73                       Trix       110  27.753301
# 74                 Wheat_Chex       100  49.787445
# 75                   Wheaties       100  51.592193
# 76        Wheaties_Honey_Gold       110  36.187559
#
# [77 rows x 3 columns]
